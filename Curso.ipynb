# %% [markdown]
# <a href="https://colab.research.google.com/github/lilitatiana515-dotcom/IA-II/blob/main/Curso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Introduction to Computer Science
# -CS 50 - Introduction to Computer Science (Harvard University)
# -6.0001 - Introduction to Computer Science and Programming in Python (MIT OCW)
#
# 2. Data Structures and Algorithms
#  - 6.0006 - Introduction to Algorithms (MIT OCW)   -COS 226 Algorithms (Princeton University - Robert Sedgewick & Kevin Wayne)
#
# 3. Systems Programming (incluye Operating Systems, Distributed Systems y Real-Time Systems)
#   - CS 161 - Operating Systems (Harvard University)
#   - 6.824 - Distributed Systems (MIT)
#
# 4. Database Systems
#     - 15-445/645 - Database Systems (Carnegie Mellon University - CMU)
#     - CS 145 - Introduction to Databases (Stanford University)
#
# 5. Software Engineering (incluye Object Oriented Design, Architecture y Concurrency)
# -  Computer Science 169- Software Engineering (UC Berkeley)
# -CS 411 - Software Architecture Design (Bilkent University)
#
# 6. Artificial Intelligence
# -CS 188 - Introduction to Artificial Intelligence (UC Berkeley)
# -6.034 - Artificial Intelligence (MIT OCW)
#
# 7. Machine Learning (incluye Deep Learning, NLP, CV, Reinforcement Learning, etc.)
# -CS 229 - Machine Learning (Stanford University)   -CS 231n - Convolutional Neural Networks for Visual Recognition (Stanford University)
#
# 8. Computer Networks
# -CS 144 - Introduction to Computer Networking (Stanford University)
# -Computer Networks (University of Washington)
#
# 9. Math for Computer Scientist
# -6.042J - Mathematics for Computer Science (MIT OCW)
# -CS 103 - Mathematical Foundations of Computing (Stanford University)
#
# 10. Web Programming and Internet Technologies   -CS50W - CS50's Web Programming with Python and JavaScript (Harvard University)
# -CS 142 - Web Applications (Stanford University)
#
# 11. Theoretical CS and Programming Languages
#
# -CS 143 - Compilers (Stanford University)
# -6.045J - Automata, Computability, and Complexity (MIT OCW)
#
# 12. Embedded Systems
# -UT.6.01x - Embedded Systems - Shape the World (UT Austin)
# -Embedded Systems (IIT Kharagpur)
#
# 13. Real time system evaluation
# -Real-Time Systems (IIT Kharagpur)
# -ECE 4580 - Real-Time Embedded Systems (Cornell University)
#
# 14. Computer Organization and Architecture
# -CS 61C - Great Ideas in Computer Architecture (Machine Structures) (UC Berkeley)
# -15-213 - Introduction to Computer Systems (Carnegie Mellon University)
#
# 15. Security
# -CS 255 - Introduction to Cryptography (Stanford University)
# -CS 155 - Computer and Network Security (Stanford University)
#
# 16. Computer Graphics
# -CS 184 - Computer Graphics (UC Berkeley)
# -6.837 - Computer Graphics (MIT OCW)
#
# 17. Image Processing and Computer Vision
# -CS 231a - Computer Vision: From 3D Reconstruction to Recognition (Stanford University)   -Introduction to Computer Vision (Georgia Tech)
#
# 18. Computational Biology
# -Algorithms in Bioinformatics (UC San Diego)02-601 - Programming for Scientists (Carnegie Mellon University)
#
# 19. Quantum Computing
# -Quantum Computing and Information (University of Pittsburgh)
# -Introduction to Quantum Computing (UBC)
#
# 20. Robotics and Control
# -CS 223A - Introduction to Robotics (Stanford University)
# -Robot Mapping (University of Freiburg)
#
# 21. Computational Finance
# -Computational Finance (University of Washington)
# -15.450 - Analytics of Finance (MIT)
#
# 22. Network Science
# -CS 224W - Machine Learning with Graphs / Network Analysis (Stanford University)
# -Network Science (Northeastern University)
#
# 23. Blockchain Development
# -CS 251 - Cryptocurrencies and Blockchain Technologies (Stanford University)
# -Blockchain and Money (MIT)
