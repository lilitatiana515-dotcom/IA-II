# %% [markdown]
# <a href="https://colab.research.google.com/github/lilitatiana515-dotcom/IA-II/blob/main/Sesion5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Sesion_5.png](data:image/png;base64,...)

# %% [markdown]
# 1. Simulador Interactivo de Niveles Demo
# Entorno Jugable: Incluye los primeros juegos oficiales de ARC-AGI-3 (ls20 Locksmith, ft09 Elementary Logic y vc33 Orchestration), con sus niveles 1, 2 y 3.
# Motor de Reglas y Física ARC: Reproduce fielmente la interacción de entidades: llaves (amarilla 4, azul 1), puertas bloqueadas (roja 2, magenta 6), bloques empujables Sokoban (9), interruptores y el portal de meta (3).
# Controles Oficiales y Teclado: Soporte para las acciones oficiales (RESET, ACTION1 a ACTION7) tanto con mando virtual en pantalla como mediante el teclado (W/A/S/D, Espacio, Q, R y Z).
# Métrica RHAE en Tiempo Real: Calcula tu puntuación de eficiencia comparando tus acciones tomadas contra la línea base de referencia humana.
# 2. Co-Piloto de Razonamiento IA (Gemini 3.8 Flash + Solucionador Óptimo)
# Diagnóstico Automático: Con un solo clic en "Pedir Solución IA", el sistema analiza el estado actual de la cuadrícula, deduce la regla oculta del nivel y desglosa las entidades (agente, meta, obstáculos, cerraduras).
# Secuencia de Movimientos Paso a Paso: Te entrega la lista exacta de teclas recomendadas para resolver el nivel con el menor número de acciones posibles.
# Modo Auto-Play: Puedes ver a la IA ejecutar su propio plan paso a paso sobre el tablero animado.
# 3. Lector Visual de Capturas (Ctrl + V)
# Si estás jugando directamente en el sitio web de arcprize.org/arc-agi/3, puedes tomar una captura de pantalla (con Win + Shift + S en Windows o Cmd + Shift + 4 en Mac) y pegarla directamente (Ctrl + V) o arrastrarla a la pestaña Lector de Capturas.
# El modelo multimodal de Gemini lee los colores de tu partida, identifica el juego y te indica cómo superarlo.
# 4. Editor y Diseñador de Cuadrículas ARC
# Te permite pintar libremente con la paleta de 10 colores estándar de ARC o pegar matrices en formato JSON ([[5,5,5], ...] o formato de tarea ARC) para probar soluciones personalizadas.
# 5. Guía Estratégica y Trucos Integrada
# Incluye un modal con la "Guía y Trucos" que explica:
# El significado común de cada color en ARC-AGI-3.
# La lógica de cadenas de dependencia (por ejemplo, en ls20: Llave Amarilla
#  Puerta Roja
#  Llave Azul
#  Puerta Magenta
#  Meta Verde).
# Consejos para evitar encajonar bloques empujables y maximizar tu puntuación.
